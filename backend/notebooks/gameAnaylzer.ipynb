# %%
from bs4 import BeautifulSoup
import requests
#USE PYTHON ANACADONA 3.8.5 to RUN

# %%
url= "http://onlinecollegebasketball.org/game/1005254"
page = requests.get(url)
soup = BeautifulSoup(page.text,"html")

# %%
infoList = soup.find_all("td",class_="left")



#'''
gameData = {
  "awayTeam":{
    "name": infoList[1].text.replace("\xa0"," "),
    "teamCode":(infoList[1].find("a").get("href")).split("/")[2],
    "players":[],
    "totalShots":{"Finishing": [0, 0], "Inside Shot": [0, 0], "Mid-Range": [0, 0], "3-Pointer": [0, 0]},
    "totalDriving":[0,0],
    "defense" : {"man-to-man": {"Finishing": [0, 0], "Inside Shot": [0, 0], "Mid-Range": [0, 0], "3-Pointer": [0, 0], "Turnovers": [0, 0]},
                 "man-to-man defense packed" : {"Finishing": [0, 0], "Inside Shot": [0, 0], "Mid-Range": [0, 0], "3-Pointer": [0, 0], "Turnovers": [0, 0]},
                 "man-to-man defense extended" : {"Finishing": [0, 0], "Inside Shot": [0, 0], "Mid-Range": [0, 0], "3-Pointer": [0, 0], "Turnovers": [0, 0]},    
    "zone":{"Finishing": [0, 0], "Inside Shot": [0, 0], "Mid-Range": [0, 0], "3-Pointer": [0, 0], "Turnovers": [0, 0]},
    "zone defense packed":{"Finishing": [0, 0], "Inside Shot": [0, 0], "Mid-Range": [0, 0], "3-Pointer": [0, 0], "Turnovers": [0, 0]},
    "zone defense extended":{"Finishing": [0, 0], "Inside Shot": [0, 0], "Mid-Range": [0, 0], "3-Pointer": [0, 0], "Turnovers": [0, 0]},
    "pressure":{"Finishing": [0, 0], "Inside Shot": [0, 0], "Mid-Range": [0, 0], "3-Pointer": [0, 0], "Turnovers": [0, 0]},
    "transition": {"Finishing": [0, 0], "Inside Shot": [0, 0], "Mid-Range": [0, 0], "3-Pointer": [0, 0], "Turnovers": [0, 0]},
    "half-court": {"Finishing": [0, 0], "Inside Shot": [0, 0], "Mid-Range": [0, 0], "3-Pointer": [0, 0], "Turnovers": [0, 0]}}
  }
  ,
  "homeTeam":{
    "name": infoList[2].text.replace("\xa0"," "),
    "teamCode":(infoList[2].find("a").get("href")).split("/")[2],
    "players":[],
    "totalShots":{"Finishing": [0, 0], "Inside Shot": [0, 0], "Mid-Range": [0, 0], "3-Pointer": [0, 0]},
    "totalDriving":[0,0],
    "defense" : {"man-to-man": {"Finishing": [0, 0], "Inside Shot": [0, 0], "Mid-Range": [0, 0], "3-Pointer": [0, 0], "Turnovers": [0, 0]},
                 "man-to-man defense packed" : {"Finishing": [0, 0], "Inside Shot": [0, 0], "Mid-Range": [0, 0], "3-Pointer": [0, 0], "Turnovers": [0, 0]},
                 "man-to-man defense extended" : {"Finishing": [0, 0], "Inside Shot": [0, 0], "Mid-Range": [0, 0], "3-Pointer": [0, 0], "Turnovers": [0, 0]},    
    "zone":{"Finishing": [0, 0], "Inside Shot": [0, 0], "Mid-Range": [0, 0], "3-Pointer": [0, 0], "Turnovers": [0, 0]},
    "zone defense packed":{"Finishing": [0, 0], "Inside Shot": [0, 0], "Mid-Range": [0, 0], "3-Pointer": [0, 0], "Turnovers": [0, 0]},
    "zone defense extended":{"Finishing": [0, 0], "Inside Shot": [0, 0], "Mid-Range": [0, 0], "3-Pointer": [0, 0], "Turnovers": [0, 0]},
    "pressure":{"Finishing": [0, 0], "Inside Shot": [0, 0], "Mid-Range": [0, 0], "3-Pointer": [0, 0], "Turnovers": [0, 0]},
    "transition": {"Finishing": [0, 0], "Inside Shot": [0, 0], "Mid-Range": [0, 0], "3-Pointer": [0, 0], "Turnovers": [0, 0]},
    "half-court": {"Finishing": [0, 0], "Inside Shot": [0, 0], "Mid-Range": [0, 0], "3-Pointer": [0, 0], "Turnovers": [0, 0]}}
  }
}
  

#'''

# %%
teamSwitch = 0 
curTeam = "awayTeam"
infoListPlayers = infoList[4:]  # cuts it to the first player in BoxScore

for i in range(len(infoListPlayers)):
    if len(infoListPlayers[i].text.split("\xa0")) == 3:
        name, position = infoListPlayers[i].text.split("\xa0")[1:]
        print(name,position)
        # Append a new player dictionary if the player index exceeds the current list length
        if len(gameData[curTeam]["players"]) <= i:
            gameData[curTeam]["players"].append({"name": name, "position": position.upper(), "shots": {"Finishing": [0, 0], "Inside Shot": [0, 0], "Mid-Range": [0, 0], "3-Pointer": [0, 0]}, "driving": [0, 0]})
        else:
            # Update existing player information
            gameData[curTeam]["players"][i]["name"] = name
            gameData[curTeam]["players"][i]["position"] = position.upper()
            gameData[curTeam]["players"][i]["shots"] = {"Finishing": [0, 0], "Inside Shot": [0, 0], "Mid-Range": [0, 0], "3-Pointer": [0, 0]}
            gameData[curTeam]["players"][i]["driving"] = [0, 0]

        # Switch the team if the next player is "Total" and the current team is "homeTeam"
        if infoListPlayers[i + 1].text == "Total" and curTeam == "awayTeam":
            curTeam = "homeTeam"
# Out:
# D. Vail sf
# L. Corrales pf
# R. Dolf c
# P. McNeil sg
# I. Ziegler pg
# C. Harding pf
# K. Temple sg
# M. Smith c
# I. Pruitt sf
# L. Lewis pf
# B. Lay c
# M. Jaramillo sg
# G. Munoz pg
# W. Murphy pg
# B. Black sg
# J. Schwarz c
# T. Perkins sg

# %%
playbyText = soup.find_all("div",id="Boxscore")[1].text
gameArr = playbyText.split("\n")
tipOff = gameArr[10]

# %%
x = soup.find_all("div",id="Boxscore")[1]
teamEventArr = x.find_all("b")[3:] #shows time and Team for each play-by-play Event (lined up with gameStartArr)

#Lines up the events of gameEventsArr and teamEventArr
gameEventsArr = gameArr[10:] # play-by-play Events
for i in gameEventsArr:
  if i == "":
    gameEventsArr.remove(i)

# %%
#Changes all Exclamations to Periods
for i in range(len(gameEventsArr)):
  gameEventsArr[i] = gameEventsArr[i].replace("!",".")
gameEventsArr = gameEventsArr[:-1]

# %%
#Delete "Game Event","2nd Half","Overtime" and lines w/o ":" from gameEventsArr 
'''
gameEventsArr = [string for string in gameEventsArr if "Game Event" not in string]
gameEventsArr = [string for string in gameEventsArr if "2nd Half" not in string]
gameEventsArr = [string for string in gameEventsArr if "Overtime" not in string]
gameEventsArr = [string for string in gameEventsArr if ":" in string]
'''
gameEventsArr = [
    string for string in gameEventsArr
    if "Game Event" not in string
    and "2nd Half" not in string
    and "Overtime" not in string
    and ":" in string
]

# %%
#Deletes time of play-by-play, Makes it easier to get the Offensive Team


for i in range(len(gameEventsArr)):
  dash = "-"
  index = 0
  while(dash != gameEventsArr[i][index]):
      index += 1
  gameEventsArr[i] = gameEventsArr[i][index + 2:]

# %%
#Determines whether a drive is successful or not
Driving = {
  "Fail":"drive ",
  "Success":"drives "
}

# %%
#Adds all the drivers
drive_attempt = -1 #-1: No Drive, 0: Fail, 1: Success
for event in gameEventsArr:
  if Driving["Fail"] in event or Driving["Success"] in event:
    drive_attempt = 0
    if Driving["Success"] in event:
      drive_attempt = 1
    words = event.split()
    team = words[0][:-1] #team of driver
    if drive_attempt == 0:
      drive_index = words.index("drive")
      player_index = drive_index - 3
    else:
      drive_index = words.index("drives")
      player_index = drive_index - 1
    player_name = words[player_index] #driver name

    
    if team in gameData["homeTeam"]["name"]:
      team = "homeTeam"
    else:
      team = "awayTeam"
    
    for player in gameData[team]["players"]:
      if player["name"] == player_name:
        player["driving"][0] += drive_attempt
        player["driving"][1] += 1
        gameData[team]["totalDriving"][0] += drive_attempt
        gameData[team]["totalDriving"][1] += 1

# %%
#Delete Game Events with Non-And One Fouls (second free throws occur) and Charging Fouls
gameEventsArr = [string for string in gameEventsArr if "second free throw" not in string or "blocking out" in string]
gameEventsArr = [string for string in gameEventsArr if "charged with the foul" not in string]

# %%
shotTypes = {    
    "Inside Shot": ["shoots from the inside","shoots from the low post", "shoots in the paint", "shoots from inside the arc", "shoots from the block","tips it in","attempts to dunk it" , "lays it up", "goes for the dunk"],
    "Mid-Range": ["with a fadeaway jumper","shoots a jumper"],
    "3-Pointer": ["shoots from beyond the arc","shoots from well beyond the arc","shoots from the three point line", "shoots from deep" , "shoots from the corner","shoots from downtown"]
}

Finishing = {"attempts to dunk it" , "lays it up", "goes for the dunk"}

Turnover = {"turns the ball over", "steals the pass"}

# %%
#Adds every FG into the gameData per Player
for event in gameEventsArr:
  if "pressure" in event:
    print(event)
  #Adds turnovers in defense (not offensive fouls)
  if "turns the ball over" in event or "steals the pass" in event:

    words = event.split()
    team = words[0][:-1]
    if team in gameData["homeTeam"]["name"]:
      team = "homeTeam"
      oppTeam = "awayTeam"  
    else:
      team = "awayTeam"
      oppTeam = "homeTeam"

    try:
      defense = [defense for defense in gameData["awayTeam"]["defense"] if defense in event][-1]
      
    except IndexError:
      #print(event)
      defense = "half-court"
    
    
    gameData[oppTeam]["defense"][defense]["Turnovers"][0] += 1
    gameData[oppTeam]["defense"][defense]["Turnovers"][1] += 1 #Defense event counter [forced turnovers,defensive events occured]
    
  #For searching shots
  for shot_type, shots in shotTypes.items():
    for shot in shots:
      shot_attempt = 0
      if shot in event:
        words = event.split()
        player_index = words.index(shot.split()[0]) - 1
        player_name = words[player_index]
        team = words[0][:-1]

        

        #Finds the type of defense (doesn't matter for gameData["team"])
        try:
          defense = [defense for defense in gameData["awayTeam"]["defense"] if defense in event][-1]
          
          

        except IndexError:
          defense = "half-court"
        
        

        if "Slam dunk" in event or "shot goes in" in event or "tips it in" == shot:
          shot_attempt = 1
        

        #For Fast-breaks

        if ("Breakaway" in event or "Fast break opportunity" in event) and "slow it down" not in event:
          defense = "transition"
          if shot in Finishing:
            shot_type = "Finishing"

        #For Drives
        if shot in Finishing and "drives" in event and words[words.index("drives") - 1] == player_name:
          shot_type = "Finishing"
        
        
            

        #finds player and accumlates the shot in gameData
        if team in gameData["homeTeam"]["name"]:
          team = "homeTeam"
          oppTeam = "awayTeam"
          
        else:
          team = "awayTeam"
          oppTeam = "homeTeam"
        
        
          
      
        for player in gameData[team]["players"]:
          
          
          
          if player["name"] == player_name:
            
            player["shots"][shot_type][0] += shot_attempt
            player["shots"][shot_type][1] += 1
            gameData[team]["totalShots"][shot_type][0] += shot_attempt
            gameData[team]["totalShots"][shot_type][1] += 1

            gameData[oppTeam]["defense"][defense][shot_type][0] += shot_attempt
            gameData[oppTeam]["defense"][defense][shot_type][1] += 1

            #print(defense)
            gameData[oppTeam]["defense"][defense]["Turnovers"][1] += 1 #Defense event counter [forced turnovers,defensive events occured]

gameData
# Out:
# American International: Ziegler brings up the ball against pressure defense.   Ziegler passes the ball to Smith in the paint. Smith passes the ball to Ziegler in the paint. Ziegler shoots from the low post.  The shot goes in.   Assisted by Smith.   Tied 9 - 9.
# American International: Temple brings up the ball against pressure defense.   Temple passes the ball to McNeil on the perimeter. McNeil shoots from the three point line.  The shot misses.   Lewis grabs the rebound.
# American International: McNeil brings up the ball against pressure defense.   McNeil passes the ball to Temple on the perimeter. Temple shoots from beyond the arc.  The shot goes in.   Assisted by McNeil.   Tied 16 - 16.
# American International: McNeil brings up the ball against pressure defense.   McNeil passes the ball to Temple. Temple passes the ball to McNeil on the perimeter. McNeil passes the ball to Vail outside. Vail passes the ball to McNeil. McNeil passes the ball to Vail in the paint. Foul.  Jaramillo commits a foul away from the ball.
# American International: McNeil brings up the ball against pressure defense.   McNeil passes the ball to Harding in the paint. Harding passes the ball to Temple. Temple shoots a jumper from the elbow.  The shot goes in.   Assisted by Harding.   American International 23 - 21.
# Assumption: Munoz brings up the ball against pressure defense.   Munoz passes the ball to Lay in the paint. Lay passes the ball to Munoz. Offensive foul.  Munoz commits the foul.
# American International: Ziegler brings up the ball against pressure defense.   Ziegler passes the ball to Harding in the paint. Harding passes the ball to Dolf in the paint. Dolf passes the ball to Corrales on the perimeter. Corrales shoots from the three point line.  The shot goes in.   American International 28 - 23.
# Assumption: Murphy brings up the ball against pressure defense.   Murphy passes the ball to Pruitt on the perimeter. Pruitt shoots from the three point line.  The shot misses.   Corrales grabs the rebound.
# American International: McNeil brings up the ball against pressure defense.   McNeil passes the ball to Dolf in the paint. Dolf shoots in the paint.  The shot misses.   Pruitt grabs the rebound.
# American International: Ziegler brings up the ball against pressure defense.   Ziegler passes the ball to Harding in the paint. Pruitt steals the pass from Harding.
# American International: Temple brings up the ball against pressure defense.   Temple passes the ball to Ziegler in the paint. Ziegler passes the ball to Harding on the perimeter. Harding passes the ball to Ziegler in the paint. Ziegler passes the ball to Dolf in the paint. Dolf passes the ball to Ziegler outside. Ziegler shoots from well beyond the arc.  The shot misses.   Schwarz grabs the rebound.
# American International: Ziegler brings up the ball against pressure defense.   Ziegler tries to drive to the basket, but is stopped.   Ziegler with a fadeaway jumper.  The shot misses.   Vail grabs the offensive rebound.
# American International: Ziegler brings up the ball against pressure defense.   Ziegler passes the ball to Temple on the perimeter. Temple shoots from beyond the arc.  The shot misses.   Dolf grabs the long offensive rebound.
# Assumption: Black brings up the ball against pressure defense.   Black drives by Ziegler.   Black lays it up.  The shot misses.   Lewis grabs the offensive rebound.
# American International: Ziegler brings up the ball against pressure defense.   Ziegler passes the ball to McNeil in the paint. McNeil shoots from the low post.  The shot goes in.   Assisted by Ziegler.   American International 52 - 36.
# American International: Ziegler brings up the ball against pressure defense.   Ziegler passes the ball to McNeil on the perimeter. McNeil passes the ball to Corrales. Corrales turns the ball over out of bounds.
# American International: Ziegler brings up the ball against pressure defense.   Ziegler passes the ball to Smith in the paint. Smith turns the ball over out of bounds.
# Assumption: Munoz brings up the ball against pressure defense.   Munoz tries to drive to the basket, but is stopped.   Munoz with a fadeaway jumper.  The shot misses.   Vail grabs the rebound.
# American International: McNeil brings up the ball against pressure defense.   McNeil passes the ball to Smith on the perimeter. Smith passes the ball to Dolf in the paint. Dolf passes the ball to Smith. Smith passes the ball to Vail. Foul.  Perkins commits the foul on Vail.
# American International: Ziegler brings up the ball against pressure defense.   Ziegler passes the ball to Corrales in the paint. Corrales passes the ball to McNeil on the perimeter. McNeil passes the ball to Harding in the paint. Harding passes the ball to Ziegler. Ziegler passes the ball to Harding in the paint. Harding shoots from the block.  The shot goes in.   Assisted by Ziegler.   American International 76 - 48.
# American International: McNeil brings up the ball against pressure defense.   McNeil passes the ball to Dolf in the paint. Dolf passes the ball to Corrales in the paint. Corrales passes the ball to Ziegler. Ziegler tries to drive to the basket, but is stopped.   Ziegler with a fadeaway jumper.  The shot goes in.   Assisted by Corrales.   American International 78 - 50.
# American International: McNeil brings up the ball against pressure defense.   McNeil passes the ball to Smith. Smith passes the ball to McNeil outside. McNeil passes the ball to Corrales in the paint. Corrales shoots in the paint.  The shot goes in.   Assisted by McNeil.   American International 82 - 54.
# American International: Ziegler brings up the ball against pressure defense.   Ziegler passes the ball to McNeil in the paint. McNeil passes the ball to Corrales outside. Corrales passes the ball to McNeil outside. McNeil passes the ball to Dolf in the paint. Dolf shoots from the low post.  The shot misses.   Pruitt grabs the rebound.
# {'awayTeam': {'name': 'American International Yellow Jackets',
#   'teamCode': '540',
#   'players': [{'name': 'D. Vail',
#     'position': 'SF',
#     'shots': {'Finishing': [0, 0],
#      'Inside Shot': [0, 0],
#      'Mid-Range': [0, 0],
#      '3-Pointer': [0, 0]},
#     'driving': [0, 0]},
#    {'name': 'L. Corrales',
#     'position': 'PF',
#     'shots': {'Finishing': [0, 0],
#      'Inside Shot': [0, 0],
#      'Mid-Range': [0, 0],
#      '3-Pointer': [0, 0]},
#     'driving': [0, 0]},
#    {'name': 'R. Dolf',
#     'position': 'C',
#     'shots': {'Finishing': [0, 0],
#      'Inside Shot': [0, 0],
#      'Mid-Range': [0, 0],
#      '3-Pointer': [0, 0]},
#     'driving': [0, 0]},
#    {'name': 'P. McNeil',
#     'position': 'SG',
#     'shots': {'Finishing': [0, 0],
#      'Inside Shot': [0, 0],
#      'Mid-Range': [0, 0],
#      '3-Pointer': [0, 0]},
#     'driving': [0, 0]},
#    {'name': 'I. Ziegler',
#     'position': 'PG',
#     'shots': {'Finishing': [0, 0],
#      'Inside Shot': [0, 0],
#      'Mid-Range': [0, 0],
#      '3-Pointer': [0, 0]},
#     'driving': [0, 0]},
#    {'name': 'C. Harding',
#     'position': 'PF',
#     'shots': {'Finishing': [0, 0],
#      'Inside Shot': [0, 0],
#      'Mid-Range': [0, 0],
#      '3-Pointer': [0, 0]},
#     'driving': [0, 0]},
#    {'name': 'K. Temple',
#     'position': 'SG',
#     'shots': {'Finishing': [0, 0],
#      'Inside Shot': [0, 0],
#      'Mid-Range': [0, 0],
#      '3-Pointer': [0, 0]},
#     'driving': [0, 0]},
#    {'name': 'M. Smith',
#     'position': 'C',
#     'shots': {'Finishing': [0, 0],
#      'Inside Shot': [0, 0],
#      'Mid-Range': [0, 0],
#      '3-Pointer': [0, 0]},
#     'driving': [0, 0]}],
#   'totalShots': {'Finishing': [0, 0],
#    'Inside Shot': [0, 0],
#    'Mid-Range': [0, 0],
#    '3-Pointer': [0, 0]},
#   'totalDriving': [0, 0],
#   'defense': {'man-to-man': {'Finishing': [0, 0],
#     'Inside Shot': [0, 0],
#     'Mid-Range': [0, 0],
#     '3-Pointer': [0, 0],
#     'Turnovers': [0, 0]},
#    'man-to-man defense packed': {'Finishing': [0, 0],
#     'Inside Shot': [0, 0],
#     'Mid-Range': [0, 0],
#     '3-Pointer': [0, 0],
#     'Turnovers': [0, 0]},
#    'man-to-man defense extended': {'Finishing': [0, 0],
#     'Inside Shot': [0, 0],
#     'Mid-Range': [0, 0],
#     '3-Pointer': [0, 0],
#     'Turnovers': [4, 4]},
#    'zone': {'Finishing': [0, 0],
#     'Inside Shot': [0, 0],
#     'Mid-Range': [0, 0],
#     '3-Pointer': [0, 0],
#     'Turnovers': [1, 1]},
#    'zone defense packed': {'Finishing': [0, 0],
#     'Inside Shot': [0, 0],
#     'Mid-Range': [0, 0],
#     '3-Pointer': [0, 0],
#     'Turnovers': [0, 0]},
#    'zone defense extended': {'Finishing': [0, 0],
#     'Inside Shot': [0, 0],
#     'Mid-Range': [0, 0],
#     '3-Pointer': [0, 0],
#     'Turnovers': [2, 2]},
#    'pressure': {'Finishing': [0, 0],
#     'Inside Shot': [0, 0],
#     'Mid-Range': [0, 0],
#     '3-Pointer': [0, 0],
#     'Turnovers': [0, 0]},
#    'transition': {'Finishing': [0, 0],
#     'Inside Shot': [0, 0],
#     'Mid-Range': [0, 0],
#     '3-Pointer': [0, 0],
#     'Turnovers': [0, 0]},
#    'half-court': {'Finishing': [0, 0],
#     'Inside Shot': [0, 0],
#     'Mid-Range': [0, 0],
#     '3-Pointer': [0, 0],
#     'Turnovers': [4, 4]}}},
#  'homeTeam': {'name': 'Assumption Greyhounds',
#   'teamCode': '533',
#   'players': [{'name': 'I. Pruitt',
#     'position': 'SF',
#     'shots': {'Finishing': [0, 0],
#      'Inside Shot': [0, 0],
#      'Mid-Range': [0, 0],
#      '3-Pointer': [0, 0]},
#     'driving': [0, 0]},
#    {'name': 'L. Lewis',
#     'position': 'PF',
#     'shots': {'Finishing': [0, 0],
#      'Inside Shot': [0, 0],
#      'Mid-Range': [0, 0],
#      '3-Pointer': [0, 0]},
#     'driving': [0, 0]},
#    {'name': 'B. Lay',
#     'position': 'C',
#     'shots': {'Finishing': [0, 0],
#      'Inside Shot': [0, 0],
#      'Mid-Range': [0, 0],
#      '3-Pointer': [0, 0]},
#     'driving': [0, 0]},
#    {'name': 'M. Jaramillo',
#     'position': 'SG',
#     'shots': {'Finishing': [0, 0],
#      'Inside Shot': [0, 0],
#      'Mid-Range': [0, 0],
#      '3-Pointer': [0, 0]},
#     'driving': [0, 0]},
#    {'name': 'G. Munoz',
#     'position': 'PG',
#     'shots': {'Finishing': [0, 0],
#      'Inside Shot': [0, 0],
#      'Mid-Range': [0, 0],
#      '3-Pointer': [0, 0]},
#     'driving': [0, 0]},
#    {'name': 'W. Murphy',
#     'position': 'PG',
#     'shots': {'Finishing': [0, 0],
#      'Inside Shot': [0, 0],
#      'Mid-Range': [0, 0],
#      '3-Pointer': [0, 0]},
#     'driving': [0, 0]},
#    {'name': 'B. Black',
#     'position': 'SG',
#     'shots': {'Finishing': [0, 0],
#      'Inside Shot': [0, 0],
#      'Mid-Range': [0, 0],
#      '3-Pointer': [0, 0]},
#     'driving': [0, 0]},
#    {'name': 'J. Schwarz',
#     'position': 'C',
#     'shots': {'Finishing': [0, 0],
#      'Inside Shot': [0, 0],
#      'Mid-Range': [0, 0],
#      '3-Pointer': [0, 0]},
#     'driving': [0, 0]},
#    {'name': 'T. Perkins',
#     'position': 'SG',
#     'shots': {'Finishing': [0, 0],
#      'Inside Shot': [0, 0],
#      'Mid-Range': [0, 0],
#      '3-Pointer': [0, 0]},
#     'driving': [0, 0]}],
#   'totalShots': {'Finishing': [0, 0],
#    'Inside Shot': [0, 0],
#    'Mid-Range': [0, 0],
#    '3-Pointer': [0, 0]},
#   'totalDriving': [0, 0],
#   'defense': {'man-to-man': {'Finishing': [0, 0],
#     'Inside Shot': [0, 0],
#     'Mid-Range': [0, 0],
#     '3-Pointer': [0, 0],
#     'Turnovers': [4, 4]},
#    'man-to-man defense packed': {'Finishing': [0, 0],
#     'Inside Shot': [0, 0],
#     'Mid-Range': [0, 0],
#     '3-Pointer': [0, 0],
#     'Turnovers': [0, 0]},
#    'man-to-man defense extended': {'Finishing': [0, 0],
#     'Inside Shot': [0, 0],
#     'Mid-Range': [0, 0],
#     '3-Pointer': [0, 0],
#     'Turnovers': [0, 0]},
#    'zone': {'Finishing': [0, 0],
#     'Inside Shot': [0, 0],
#     'Mid-Range': [0, 0],
#     '3-Pointer': [0, 0],
#     'Turnovers': [3, 3]},
#    'zone defense packed': {'Finishing': [0, 0],
#     'Inside Shot': [0, 0],
#     'Mid-Range': [0, 0],
#     '3-Pointer': [0, 0],
#     'Turnovers': [0, 0]},
#    'zone defense extended': {'Finishing': [0, 0],
#     'Inside Shot': [0, 0],
#     'Mid-Range': [0, 0],
#     '3-Pointer': [0, 0],
#     'Turnovers': [0, 0]},
#    'pressure': {'Finishing': [0, 0],
#     'Inside Shot': [0, 0],
#     'Mid-Range': [0, 0],
#     '3-Pointer': [0, 0],
#     'Turnovers': [3, 3]},
#    'transition': {'Finishing': [0, 0],
#     'Inside Shot': [0, 0],
#     'Mid-Range': [0, 0],
#     '3-Pointer': [0, 0],
#     'Turnovers': [0, 0]},
#    'half-court': {'Finishing': [0, 0],
#     'Inside Shot': [0, 0],
#     'Mid-Range': [0, 0],
#     '3-Pointer': [0, 0],
#     'Turnovers': [4, 4]}}}}

# %%
soup2 = soup #used for getting GAME CODE and GAME TYPE



date = soup2.find("div",{"id": "Main"}).find_all("h3")[0]
type_id = soup2.find("div",{"id": "Main"}).find_all("h3")[1]

first_half_months = ["October","November","December"]

date_split = date.text[7:].replace(",","").split(" ")

month = date_split[0]
year = int(date_split[-1])

if month in first_half_months:
    season = year + 1
else:
    season = year




game_type_unparsed = type_id.text[15:].split(" ")[0]
game_id_unparsed = type_id.text[15:].split(" ")[-2]

game_type = game_type_unparsed.strip("[]")

game_id = int(game_id_unparsed.strip("[]#"))
season,game_type,game_id
# Out:
# (2043, 'Non-Conference', 1005254)

# %%
gameData["season_year"] = season
gameData["game_id"] = game_id
gameData["game_type"] = game_type
gameData
# Out:
# {'awayTeam': {'name': 'American International Yellow Jackets',
#   'teamCode': '540',
#   'players': [{'name': 'D. Vail',
#     'position': 'SF',
#     'shots': {'Finishing': [0, 0],
#      'Inside Shot': [0, 0],
#      'Mid-Range': [0, 0],
#      '3-Pointer': [0, 0]},
#     'driving': [0, 0]},
#    {'name': 'L. Corrales',
#     'position': 'PF',
#     'shots': {'Finishing': [0, 0],
#      'Inside Shot': [0, 0],
#      'Mid-Range': [0, 0],
#      '3-Pointer': [0, 0]},
#     'driving': [0, 0]},
#    {'name': 'R. Dolf',
#     'position': 'C',
#     'shots': {'Finishing': [0, 0],
#      'Inside Shot': [0, 0],
#      'Mid-Range': [0, 0],
#      '3-Pointer': [0, 0]},
#     'driving': [0, 0]},
#    {'name': 'P. McNeil',
#     'position': 'SG',
#     'shots': {'Finishing': [0, 0],
#      'Inside Shot': [0, 0],
#      'Mid-Range': [0, 0],
#      '3-Pointer': [0, 0]},
#     'driving': [0, 0]},
#    {'name': 'I. Ziegler',
#     'position': 'PG',
#     'shots': {'Finishing': [0, 0],
#      'Inside Shot': [0, 0],
#      'Mid-Range': [0, 0],
#      '3-Pointer': [0, 0]},
#     'driving': [0, 0]},
#    {'name': 'C. Harding',
#     'position': 'PF',
#     'shots': {'Finishing': [0, 0],
#      'Inside Shot': [0, 0],
#      'Mid-Range': [0, 0],
#      '3-Pointer': [0, 0]},
#     'driving': [0, 0]},
#    {'name': 'K. Temple',
#     'position': 'SG',
#     'shots': {'Finishing': [0, 0],
#      'Inside Shot': [0, 0],
#      'Mid-Range': [0, 0],
#      '3-Pointer': [0, 0]},
#     'driving': [0, 0]},
#    {'name': 'M. Smith',
#     'position': 'C',
#     'shots': {'Finishing': [0, 0],
#      'Inside Shot': [0, 0],
#      'Mid-Range': [0, 0],
#      '3-Pointer': [0, 0]},
#     'driving': [0, 0]}],
#   'totalShots': {'Finishing': [0, 0],
#    'Inside Shot': [0, 0],
#    'Mid-Range': [0, 0],
#    '3-Pointer': [0, 0]},
#   'totalDriving': [0, 0],
#   'defense': {'man-to-man': {'Finishing': [0, 0],
#     'Inside Shot': [0, 0],
#     'Mid-Range': [0, 0],
#     '3-Pointer': [0, 0],
#     'Turnovers': [0, 0]},
#    'man-to-man defense packed': {'Finishing': [0, 0],
#     'Inside Shot': [0, 0],
#     'Mid-Range': [0, 0],
#     '3-Pointer': [0, 0],
#     'Turnovers': [0, 0]},
#    'man-to-man defense extended': {'Finishing': [0, 0],
#     'Inside Shot': [0, 0],
#     'Mid-Range': [0, 0],
#     '3-Pointer': [0, 0],
#     'Turnovers': [4, 4]},
#    'zone': {'Finishing': [0, 0],
#     'Inside Shot': [0, 0],
#     'Mid-Range': [0, 0],
#     '3-Pointer': [0, 0],
#     'Turnovers': [1, 1]},
#    'zone defense packed': {'Finishing': [0, 0],
#     'Inside Shot': [0, 0],
#     'Mid-Range': [0, 0],
#     '3-Pointer': [0, 0],
#     'Turnovers': [0, 0]},
#    'zone defense extended': {'Finishing': [0, 0],
#     'Inside Shot': [0, 0],
#     'Mid-Range': [0, 0],
#     '3-Pointer': [0, 0],
#     'Turnovers': [2, 2]},
#    'pressure': {'Finishing': [0, 0],
#     'Inside Shot': [0, 0],
#     'Mid-Range': [0, 0],
#     '3-Pointer': [0, 0],
#     'Turnovers': [0, 0]},
#    'transition': {'Finishing': [0, 0],
#     'Inside Shot': [0, 0],
#     'Mid-Range': [0, 0],
#     '3-Pointer': [0, 0],
#     'Turnovers': [0, 0]},
#    'half-court': {'Finishing': [0, 0],
#     'Inside Shot': [0, 0],
#     'Mid-Range': [0, 0],
#     '3-Pointer': [0, 0],
#     'Turnovers': [4, 4]}}},
#  'homeTeam': {'name': 'Assumption Greyhounds',
#   'teamCode': '533',
#   'players': [{'name': 'I. Pruitt',
#     'position': 'SF',
#     'shots': {'Finishing': [0, 0],
#      'Inside Shot': [0, 0],
#      'Mid-Range': [0, 0],
#      '3-Pointer': [0, 0]},
#     'driving': [0, 0]},
#    {'name': 'L. Lewis',
#     'position': 'PF',
#     'shots': {'Finishing': [0, 0],
#      'Inside Shot': [0, 0],
#      'Mid-Range': [0, 0],
#      '3-Pointer': [0, 0]},
#     'driving': [0, 0]},
#    {'name': 'B. Lay',
#     'position': 'C',
#     'shots': {'Finishing': [0, 0],
#      'Inside Shot': [0, 0],
#      'Mid-Range': [0, 0],
#      '3-Pointer': [0, 0]},
#     'driving': [0, 0]},
#    {'name': 'M. Jaramillo',
#     'position': 'SG',
#     'shots': {'Finishing': [0, 0],
#      'Inside Shot': [0, 0],
#      'Mid-Range': [0, 0],
#      '3-Pointer': [0, 0]},
#     'driving': [0, 0]},
#    {'name': 'G. Munoz',
#     'position': 'PG',
#     'shots': {'Finishing': [0, 0],
#      'Inside Shot': [0, 0],
#      'Mid-Range': [0, 0],
#      '3-Pointer': [0, 0]},
#     'driving': [0, 0]},
#    {'name': 'W. Murphy',
#     'position': 'PG',
#     'shots': {'Finishing': [0, 0],
#      'Inside Shot': [0, 0],
#      'Mid-Range': [0, 0],
#      '3-Pointer': [0, 0]},
#     'driving': [0, 0]},
#    {'name': 'B. Black',
#     'position': 'SG',
#     'shots': {'Finishing': [0, 0],
#      'Inside Shot': [0, 0],
#      'Mid-Range': [0, 0],
#      '3-Pointer': [0, 0]},
#     'driving': [0, 0]},
#    {'name': 'J. Schwarz',
#     'position': 'C',
#     'shots': {'Finishing': [0, 0],
#      'Inside Shot': [0, 0],
#      'Mid-Range': [0, 0],
#      '3-Pointer': [0, 0]},
#     'driving': [0, 0]},
#    {'name': 'T. Perkins',
#     'position': 'SG',
#     'shots': {'Finishing': [0, 0],
#      'Inside Shot': [0, 0],
#      'Mid-Range': [0, 0],
#      '3-Pointer': [0, 0]},
#     'driving': [0, 0]}],
#   'totalShots': {'Finishing': [0, 0],
#    'Inside Shot': [0, 0],
#    'Mid-Range': [0, 0],
#    '3-Pointer': [0, 0]},
#   'totalDriving': [0, 0],
#   'defense': {'man-to-man': {'Finishing': [0, 0],
#     'Inside Shot': [0, 0],
#     'Mid-Range': [0, 0],
#     '3-Pointer': [0, 0],
#     'Turnovers': [4, 4]},
#    'man-to-man defense packed': {'Finishing': [0, 0],
#     'Inside Shot': [0, 0],
#     'Mid-Range': [0, 0],
#     '3-Pointer': [0, 0],
#     'Turnovers': [0, 0]},
#    'man-to-man defense extended': {'Finishing': [0, 0],
#     'Inside Shot': [0, 0],
#     'Mid-Range': [0, 0],
#     '3-Pointer': [0, 0],
#     'Turnovers': [0, 0]},
#    'zone': {'Finishing': [0, 0],
#     'Inside Shot': [0, 0],
#     'Mid-Range': [0, 0],
#     '3-Pointer': [0, 0],
#     'Turnovers': [3, 3]},
#    'zone defense packed': {'Finishing': [0, 0],
#     'Inside Shot': [0, 0],
#     'Mid-Range': [0, 0],
#     '3-Pointer': [0, 0],
#     'Turnovers': [0, 0]},
#    'zone defense extended': {'Finishing': [0, 0],
#     'Inside Shot': [0, 0],
#     'Mid-Range': [0, 0],
#     '3-Pointer': [0, 0],
#     'Turnovers': [0, 0]},
#    'pressure': {'Finishing': [0, 0],
#     'Inside Shot': [0, 0],
#     'Mid-Range': [0, 0],
#     '3-Pointer': [0, 0],
#     'Turnovers': [3, 3]},
#    'transition': {'Finishing': [0, 0],
#     'Inside Shot': [0, 0],
#     'Mid-Range': [0, 0],
#     '3-Pointer': [0, 0],
#     'Turnovers': [0, 0]},
#    'half-court': {'Finishing': [0, 0],
#     'Inside Shot': [0, 0],
#     'Mid-Range': [0, 0],
#     '3-Pointer': [0, 0],
#     'Turnovers': [4, 4]}}},
#  'season_year': 2043,
#  'game_id': 1005254,
#  'game_type': 'Non-Conference'}
